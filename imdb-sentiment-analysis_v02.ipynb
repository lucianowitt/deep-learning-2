# %% [markdown]
# ## Análise de sentimento em reviews de filmes
#
# Gibson Weinert, Luciano Gonçalves, João Paulo Medeiros
#
# ### Dataset
#
# https://www.kaggle.com/c/sentiment-analysis-on-movie-reviews/data
#
# ### Classes
# 1. negative
# 2. somewhat negative
# 3. neutral
# 4. somewhat positive
# 5. positive

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### Análise inicial dos dados

# %%
import numpy as np
import pandas as pd

# %%
original_train = pd.read_csv('./data/train.tsv', '\t')
print(original_train.shape)
original_train.head()
# Out:
# (156060, 4)
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
original_test = pd.read_csv('./data/test.tsv', '\t')
print(original_test.shape)
original_test.head()
# Out:
# (66292, 3)
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545  An intermittently pleasing but mostly routine ...
# 1    156062        8545  An intermittently pleasing but mostly routine ...
# 2    156063        8545                                                 An
# 3    156064        8545  intermittently pleasing but mostly routine effort
# 4    156065        8545         intermittently pleasing but mostly routine

# %% [markdown]
# **O conjunto original de teste não possui as labels, pois foi concebido para o desafio.**
#
# **Vamos desconsiderá-lo e dividir o conjunto original de treino em treino, validação e teste.**

# %% [markdown]
# ### Preparação dos datasets de treino, validação e teste

# %%
from sklearn.model_selection import train_test_split

X = original_train['Phrase']
y = original_train['Sentiment']

X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, stratify=y)
X_train, X_valid, y_train, y_valid = train_test_split(X_other, y_other, test_size=0.2, stratify=y_other)

print('Train:', len(X_train), '\nValid:', len(X_valid), '\nTest: ', len(X_test), '\n\nTotal:', len(X))
# Out:
# Train: 99878
# Valid: 24970
# Test:  31212
#
# Total: 156060

# %%
train = pd.DataFrame({'y': y_train, 'X': X_train})
valid = pd.DataFrame({'y': y_train, 'X': X_train})
test = pd.DataFrame({'y': y_train, 'X': X_train})

train.to_csv('./data/train.csv', '\t', header=False, index=False)
train.to_csv('./data/valid.csv', '\t', header=False, index=False)
train.to_csv('./data/test.csv', '\t', header=False, index=False)

# %% [markdown]
# ### Criação do vocabulário

# %%
import json
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
vectorizer.fit_transform(X)

vocab = {}
vocab['word2idx'] = {'<pad>': 0, '<start>': 1, '<end>': 2, '<unk>': 3}
vocab['idx2word'] = {'0': '<pad>', '1': '<start>', '2': '<end>', '3': '<unk>'}
vocab['idx'] = [0, 1, 2, 3]

for k, v in enumerate(vectorizer.vocabulary_.keys()):
    vocab['word2idx'][v] = k + 4
    vocab['idx2word'][str(k + 4)] = v
    vocab['idx'].append(k + 4)

with open('./data/vocab.json', 'w') as outfile:
    json.dump(vocab, outfile)

vocabSize = len(vocab['idx'])

print('Vocabulary size:', vocabSize)
# Out:
# Vocabulary size: 15244

# %% [markdown]
# ### Implementação

# %%
import torch
import torch.nn as nn
from data import get_loaders
from train import train, test, check_input
import models 
from matplotlib import pyplot as plt

# %%
def plot_instance(instance_id):
    print('\nExample: ')
    print(train_loader.dataset.texts[instance_id])
    print('\nLabel Number: ')
    print(train_loader.dataset.labels[instance_id])
    print('\nLabel String: ')
    print(classes[train_loader.dataset.labels[instance_id]])

# %%
classes = [
  'negative',
  'somewhat negative',
  'neutral',
  'somewhat positive',
  'positive'
]

# %%
data_path = './data/'
batch_size = 1024
device_name = 'cuda'
nb_epochs = 20
log_interval = 5
lr = 1e-2
lr_step = 5

device = torch.device(device_name)

train_loader, valid_loader = get_loaders(
    data_path=data_path, 
    batch_size=batch_size, 
    splits=['train', 'valid'],
)

nb_words = len(train_loader.dataset.vocab)

print(
    'Train size: ', 
    len(train_loader.dataset.texts),
    len(train_loader.dataset.labels)
)
print(
    'Valid size : ', 
    len(valid_loader.dataset.texts),
    len(valid_loader.dataset.labels)
)

plot_instance(0)
plot_instance(1015)
plot_instance(5136)
plot_instance(8974)
# Out:
# Train size:  99878 99878
# Valid size :  99878 99878
#
# Example:
# rattling the viewer
#
# Label Number:
# 3
#
# Label String:
# somewhat positive
#
# Example:
# had much science
#
# Label Number:
# 3
#
# Label String:
# somewhat positive
#
# Example:
# transcends ethnic lines .
#
# Label Number:
# 1
#
# Label String:
# somewhat negative
#
# Example:
# a florid but ultimately vapid crime melodrama with lots of surface
#
# Label Number:
# 0
#
# Label String:
# negative

# %%
def average_pooling(instances, lens):
    return torch.stack([
        text[:l].mean(0) for text, l in zip(instances, lens)
    ])


class TextLSTM(nn.Module):
    def __init__(self, num_embeddings=vocabSize, embedding_dim=100):
        '''
            num_embeddings: number of words in the dictionary
            embedding_dim: size of the word-embedding vector
        '''
        super(TextLSTM, self).__init__()
        self.embedding = nn.Embedding(
            num_embeddings=num_embeddings, 
            embedding_dim=embedding_dim,
        )
        self.rnn = nn.LSTM(
            input_size=100, hidden_size=32, 
            batch_first=True, bidirectional=True,
        )
        self.fc = nn.Linear(32*2, len(classes))
        
    def forward(self, x, lengths):
        # Transforma índices das palavras em vetores 
        x = self.embedding(x)
        # Processa vetores das palavras com uma rede recorrente
        hidden, output = self.rnn(x)
        # Faz a média das ativações de todas as iterações recorrentes
        vector = average_pooling(hidden, lengths)
        # Camada linear para classificacao
        x = self.fc(vector)
        return x

# %%
model = TextLSTM()
model = model.to(device)

dummy_pred = check_input(model, device)
# Out:
# Passed

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=lr_step,)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Luciano\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
history = train(
    model=model, train_loader=train_loader, test_loader=valid_loader,
    device=device, optimizer=optimizer, lr_scheduler=lr_scheduler,
    nb_epochs=nb_epochs, log_interval=log_interval
)
# Out:
# * * * Training * * *
# Train Epoch:   1 [     0/ 99878 (0%)]	Loss: 1.633662
# Train Epoch:   1 [  5120/ 99878 (5%)]	Loss: 1.314276
# Train Epoch:   1 [ 10240/ 99878 (10%)]	Loss: 1.249944
# Train Epoch:   1 [ 15360/ 99878 (15%)]	Loss: 1.245334
# Train Epoch:   1 [ 20480/ 99878 (20%)]	Loss: 1.148697
# Train Epoch:   1 [ 25600/ 99878 (26%)]	Loss: 1.189181
# Train Epoch:   1 [ 30720/ 99878 (31%)]	Loss: 1.144222
# Train Epoch:   1 [ 35840/ 99878 (36%)]	Loss: 1.208686
# Train Epoch:   1 [ 40960/ 99878 (41%)]	Loss: 1.169365
# Train Epoch:   1 [ 46080/ 99878 (46%)]	Loss: 1.071765
# Train Epoch:   1 [ 51200/ 99878 (51%)]	Loss: 1.056716
# Train Epoch:   1 [ 56320/ 99878 (56%)]	Loss: 1.097316
# Train Epoch:   1 [ 61440/ 99878 (61%)]	Loss: 1.032748
# Train Epoch:   1 [ 66560/ 99878 (66%)]	Loss: 1.058459
# Train Epoch:   1 [ 71680/ 99878 (71%)]	Loss: 0.990728
# Train Epoch:   1 [ 76800/ 99878 (77%)]	Loss: 1.066559
# Train Epoch:   1 [ 81920/ 99878 (82%)]	Loss: 0.978132
# Train Epoch:   1 [ 87040/ 99878 (87%)]	Loss: 0.984181
# Train Epoch:   1 [ 92160/ 99878 (92%)]	Loss: 0.919002
# Train Epoch:   1 [ 97280/ 99878 (97%)]	Loss: 0.963185
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0008, Accuracy: 65711/99878 (65.79%)
#
#
# * * * Training * * *
# Train Epoch:   2 [     0/ 99878 (0%)]	Loss: 0.907256
# Train Epoch:   2 [  5120/ 99878 (5%)]	Loss: 0.864414
# Train Epoch:   2 [ 10240/ 99878 (10%)]	Loss: 0.822372
# Train Epoch:   2 [ 15360/ 99878 (15%)]	Loss: 0.830610
# Train Epoch:   2 [ 20480/ 99878 (20%)]	Loss: 0.791881
# Train Epoch:   2 [ 25600/ 99878 (26%)]	Loss: 0.812270
# Train Epoch:   2 [ 30720/ 99878 (31%)]	Loss: 0.865095
# Train Epoch:   2 [ 35840/ 99878 (36%)]	Loss: 0.853255
# Train Epoch:   2 [ 40960/ 99878 (41%)]	Loss: 0.821145
# Train Epoch:   2 [ 46080/ 99878 (46%)]	Loss: 0.829551
# Train Epoch:   2 [ 51200/ 99878 (51%)]	Loss: 0.796120
# Train Epoch:   2 [ 56320/ 99878 (56%)]	Loss: 0.856699
# Train Epoch:   2 [ 61440/ 99878 (61%)]	Loss: 0.833122
# Train Epoch:   2 [ 66560/ 99878 (66%)]	Loss: 0.822754
# Train Epoch:   2 [ 71680/ 99878 (71%)]	Loss: 0.876861
# Train Epoch:   2 [ 76800/ 99878 (77%)]	Loss: 0.846299
# Train Epoch:   2 [ 81920/ 99878 (82%)]	Loss: 0.819157
# Train Epoch:   2 [ 87040/ 99878 (87%)]	Loss: 0.799623
# Train Epoch:   2 [ 92160/ 99878 (92%)]	Loss: 0.811014
# Train Epoch:   2 [ 97280/ 99878 (97%)]	Loss: 0.806122
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0007, Accuracy: 71513/99878 (71.60%)
#
#
# * * * Training * * *
# Train Epoch:   3 [     0/ 99878 (0%)]	Loss: 0.737671
# Train Epoch:   3 [  5120/ 99878 (5%)]	Loss: 0.677409
# Train Epoch:   3 [ 10240/ 99878 (10%)]	Loss: 0.690048
# Train Epoch:   3 [ 15360/ 99878 (15%)]	Loss: 0.692712
# Train Epoch:   3 [ 20480/ 99878 (20%)]	Loss: 0.752778
# Train Epoch:   3 [ 25600/ 99878 (26%)]	Loss: 0.692794
# Train Epoch:   3 [ 30720/ 99878 (31%)]	Loss: 0.703324
# Train Epoch:   3 [ 35840/ 99878 (36%)]	Loss: 0.745537
# Train Epoch:   3 [ 40960/ 99878 (41%)]	Loss: 0.710645
# Train Epoch:   3 [ 46080/ 99878 (46%)]	Loss: 0.704739
# Train Epoch:   3 [ 51200/ 99878 (51%)]	Loss: 0.723765
# Train Epoch:   3 [ 56320/ 99878 (56%)]	Loss: 0.704894
# Train Epoch:   3 [ 61440/ 99878 (61%)]	Loss: 0.691289
# Train Epoch:   3 [ 66560/ 99878 (66%)]	Loss: 0.719584
# Train Epoch:   3 [ 71680/ 99878 (71%)]	Loss: 0.777486
# Train Epoch:   3 [ 76800/ 99878 (77%)]	Loss: 0.760492
# Train Epoch:   3 [ 81920/ 99878 (82%)]	Loss: 0.729043
# Train Epoch:   3 [ 87040/ 99878 (87%)]	Loss: 0.784917
# Train Epoch:   3 [ 92160/ 99878 (92%)]	Loss: 0.745289
# Train Epoch:   3 [ 97280/ 99878 (97%)]	Loss: 0.743538
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0006, Accuracy: 74734/99878 (74.83%)
#
#
# * * * Training * * *
# Train Epoch:   4 [     0/ 99878 (0%)]	Loss: 0.650381
# Train Epoch:   4 [  5120/ 99878 (5%)]	Loss: 0.635937
# Train Epoch:   4 [ 10240/ 99878 (10%)]	Loss: 0.643877
# Train Epoch:   4 [ 15360/ 99878 (15%)]	Loss: 0.719161
# Train Epoch:   4 [ 20480/ 99878 (20%)]	Loss: 0.646647
# Train Epoch:   4 [ 25600/ 99878 (26%)]	Loss: 0.606300
# Train Epoch:   4 [ 30720/ 99878 (31%)]	Loss: 0.641874
# Train Epoch:   4 [ 35840/ 99878 (36%)]	Loss: 0.671632
# Train Epoch:   4 [ 40960/ 99878 (41%)]	Loss: 0.635362
# Train Epoch:   4 [ 46080/ 99878 (46%)]	Loss: 0.686359
# Train Epoch:   4 [ 51200/ 99878 (51%)]	Loss: 0.632338
# Train Epoch:   4 [ 56320/ 99878 (56%)]	Loss: 0.676584
# Train Epoch:   4 [ 61440/ 99878 (61%)]	Loss: 0.678184
# Train Epoch:   4 [ 66560/ 99878 (66%)]	Loss: 0.716548
# Train Epoch:   4 [ 71680/ 99878 (71%)]	Loss: 0.679556
# Train Epoch:   4 [ 76800/ 99878 (77%)]	Loss: 0.723744
# Train Epoch:   4 [ 81920/ 99878 (82%)]	Loss: 0.699026
# Train Epoch:   4 [ 87040/ 99878 (87%)]	Loss: 0.675245
# Train Epoch:   4 [ 92160/ 99878 (92%)]	Loss: 0.633958
# Train Epoch:   4 [ 97280/ 99878 (97%)]	Loss: 0.708845
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0006, Accuracy: 77008/99878 (77.10%)
#
#
# * * * Training * * *
# Train Epoch:   5 [     0/ 99878 (0%)]	Loss: 0.556485
# Train Epoch:   5 [  5120/ 99878 (5%)]	Loss: 0.556839
# Train Epoch:   5 [ 10240/ 99878 (10%)]	Loss: 0.569493
# Train Epoch:   5 [ 15360/ 99878 (15%)]	Loss: 0.630655
# Train Epoch:   5 [ 20480/ 99878 (20%)]	Loss: 0.554226
# Train Epoch:   5 [ 25600/ 99878 (26%)]	Loss: 0.591821
# Train Epoch:   5 [ 30720/ 99878 (31%)]	Loss: 0.581435
# Train Epoch:   5 [ 35840/ 99878 (36%)]	Loss: 0.635912
# Train Epoch:   5 [ 40960/ 99878 (41%)]	Loss: 0.607176
# Train Epoch:   5 [ 46080/ 99878 (46%)]	Loss: 0.613087
# Train Epoch:   5 [ 51200/ 99878 (51%)]	Loss: 0.628185
# Train Epoch:   5 [ 56320/ 99878 (56%)]	Loss: 0.562439
# Train Epoch:   5 [ 61440/ 99878 (61%)]	Loss: 0.589399
# Train Epoch:   5 [ 66560/ 99878 (66%)]	Loss: 0.642713
# Train Epoch:   5 [ 71680/ 99878 (71%)]	Loss: 0.622098
# Train Epoch:   5 [ 76800/ 99878 (77%)]	Loss: 0.611424
# Train Epoch:   5 [ 81920/ 99878 (82%)]	Loss: 0.618757
# Train Epoch:   5 [ 87040/ 99878 (87%)]	Loss: 0.621470
# Train Epoch:   5 [ 92160/ 99878 (92%)]	Loss: 0.652406
# Train Epoch:   5 [ 97280/ 99878 (97%)]	Loss: 0.663213
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0005, Accuracy: 79014/99878 (79.11%)
#
#
# * * * Training * * *
# Train Epoch:   6 [     0/ 99878 (0%)]	Loss: 0.506576
# Train Epoch:   6 [  5120/ 99878 (5%)]	Loss: 0.509872
# Train Epoch:   6 [ 10240/ 99878 (10%)]	Loss: 0.496435
# Train Epoch:   6 [ 15360/ 99878 (15%)]	Loss: 0.540334
# Train Epoch:   6 [ 20480/ 99878 (20%)]	Loss: 0.524146
# Train Epoch:   6 [ 25600/ 99878 (26%)]	Loss: 0.496117
# Train Epoch:   6 [ 30720/ 99878 (31%)]	Loss: 0.509796
# Train Epoch:   6 [ 35840/ 99878 (36%)]	Loss: 0.472671
# Train Epoch:   6 [ 40960/ 99878 (41%)]	Loss: 0.516972
# Train Epoch:   6 [ 46080/ 99878 (46%)]	Loss: 0.482651
# Train Epoch:   6 [ 51200/ 99878 (51%)]	Loss: 0.552871
# Train Epoch:   6 [ 56320/ 99878 (56%)]	Loss: 0.529644
# Train Epoch:   6 [ 61440/ 99878 (61%)]	Loss: 0.507278
# Train Epoch:   6 [ 66560/ 99878 (66%)]	Loss: 0.512367
# Train Epoch:   6 [ 71680/ 99878 (71%)]	Loss: 0.507158
# Train Epoch:   6 [ 76800/ 99878 (77%)]	Loss: 0.502633
# Train Epoch:   6 [ 81920/ 99878 (82%)]	Loss: 0.499504
# Train Epoch:   6 [ 87040/ 99878 (87%)]	Loss: 0.507932
# Train Epoch:   6 [ 92160/ 99878 (92%)]	Loss: 0.507177
# Train Epoch:   6 [ 97280/ 99878 (97%)]	Loss: 0.506015
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0005, Accuracy: 80365/99878 (80.46%)
#
#
# * * * Training * * *
# Train Epoch:   7 [     0/ 99878 (0%)]	Loss: 0.496800
# Train Epoch:   7 [  5120/ 99878 (5%)]	Loss: 0.470997
# Train Epoch:   7 [ 10240/ 99878 (10%)]	Loss: 0.490303
# Train Epoch:   7 [ 15360/ 99878 (15%)]	Loss: 0.508537
# Train Epoch:   7 [ 20480/ 99878 (20%)]	Loss: 0.467827
# Train Epoch:   7 [ 25600/ 99878 (26%)]	Loss: 0.450388
# Train Epoch:   7 [ 30720/ 99878 (31%)]	Loss: 0.483988
# Train Epoch:   7 [ 35840/ 99878 (36%)]	Loss: 0.536297
# Train Epoch:   7 [ 40960/ 99878 (41%)]	Loss: 0.487767
# Train Epoch:   7 [ 46080/ 99878 (46%)]	Loss: 0.479312
# Train Epoch:   7 [ 51200/ 99878 (51%)]	Loss: 0.508219
# Train Epoch:   7 [ 56320/ 99878 (56%)]	Loss: 0.496563
# Train Epoch:   7 [ 61440/ 99878 (61%)]	Loss: 0.496090
# Train Epoch:   7 [ 66560/ 99878 (66%)]	Loss: 0.500620
# Train Epoch:   7 [ 71680/ 99878 (71%)]	Loss: 0.450050
# Train Epoch:   7 [ 76800/ 99878 (77%)]	Loss: 0.500535
# Train Epoch:   7 [ 81920/ 99878 (82%)]	Loss: 0.486811
# Train Epoch:   7 [ 87040/ 99878 (87%)]	Loss: 0.484342
# Train Epoch:   7 [ 92160/ 99878 (92%)]	Loss: 0.505352
# Train Epoch:   7 [ 97280/ 99878 (97%)]	Loss: 0.489549
# * * * Evaluating * * *
# Test set: Average loss: 0.0005, Accuracy: 81171/99878 (81.27%)
#
#
# * * * Training * * *
# Train Epoch:   8 [     0/ 99878 (0%)]	Loss: 0.493416
# Train Epoch:   8 [  5120/ 99878 (5%)]	Loss: 0.467222
# Train Epoch:   8 [ 10240/ 99878 (10%)]	Loss: 0.463840
# Train Epoch:   8 [ 15360/ 99878 (15%)]	Loss: 0.466745
# Train Epoch:   8 [ 20480/ 99878 (20%)]	Loss: 0.489739
# Train Epoch:   8 [ 25600/ 99878 (26%)]	Loss: 0.456809
# Train Epoch:   8 [ 30720/ 99878 (31%)]	Loss: 0.499045
# Train Epoch:   8 [ 35840/ 99878 (36%)]	Loss: 0.437301
# Train Epoch:   8 [ 40960/ 99878 (41%)]	Loss: 0.445985
# Train Epoch:   8 [ 46080/ 99878 (46%)]	Loss: 0.495258
# Train Epoch:   8 [ 51200/ 99878 (51%)]	Loss: 0.511130
# Train Epoch:   8 [ 56320/ 99878 (56%)]	Loss: 0.460938
# Train Epoch:   8 [ 61440/ 99878 (61%)]	Loss: 0.450615
# Train Epoch:   8 [ 66560/ 99878 (66%)]	Loss: 0.461788
# Train Epoch:   8 [ 71680/ 99878 (71%)]	Loss: 0.460630
# Train Epoch:   8 [ 76800/ 99878 (77%)]	Loss: 0.468563
# Train Epoch:   8 [ 81920/ 99878 (82%)]	Loss: 0.480713
# Train Epoch:   8 [ 87040/ 99878 (87%)]	Loss: 0.495186
# Train Epoch:   8 [ 92160/ 99878 (92%)]	Loss: 0.480456
# Train Epoch:   8 [ 97280/ 99878 (97%)]	Loss: 0.476587
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 81810/99878 (81.91%)
#
#
# * * * Training * * *
# Train Epoch:   9 [     0/ 99878 (0%)]	Loss: 0.469641
# Train Epoch:   9 [  5120/ 99878 (5%)]	Loss: 0.423213
# Train Epoch:   9 [ 10240/ 99878 (10%)]	Loss: 0.452990
# Train Epoch:   9 [ 15360/ 99878 (15%)]	Loss: 0.469997
# Train Epoch:   9 [ 20480/ 99878 (20%)]	Loss: 0.471058
# Train Epoch:   9 [ 25600/ 99878 (26%)]	Loss: 0.433783
# Train Epoch:   9 [ 30720/ 99878 (31%)]	Loss: 0.453363
# Train Epoch:   9 [ 35840/ 99878 (36%)]	Loss: 0.452332
# Train Epoch:   9 [ 40960/ 99878 (41%)]	Loss: 0.428581
# Train Epoch:   9 [ 46080/ 99878 (46%)]	Loss: 0.490127
# Train Epoch:   9 [ 51200/ 99878 (51%)]	Loss: 0.495729
# Train Epoch:   9 [ 56320/ 99878 (56%)]	Loss: 0.421014
# Train Epoch:   9 [ 61440/ 99878 (61%)]	Loss: 0.456639
# Train Epoch:   9 [ 66560/ 99878 (66%)]	Loss: 0.462467
# Train Epoch:   9 [ 71680/ 99878 (71%)]	Loss: 0.472978
# Train Epoch:   9 [ 76800/ 99878 (77%)]	Loss: 0.440815
# Train Epoch:   9 [ 81920/ 99878 (82%)]	Loss: 0.468093
# Train Epoch:   9 [ 87040/ 99878 (87%)]	Loss: 0.473252
# Train Epoch:   9 [ 92160/ 99878 (92%)]	Loss: 0.427167
# Train Epoch:   9 [ 97280/ 99878 (97%)]	Loss: 0.454254
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 82290/99878 (82.39%)
#
#
# * * * Training * * *
# Train Epoch:  10 [     0/ 99878 (0%)]	Loss: 0.396945
# Train Epoch:  10 [  5120/ 99878 (5%)]	Loss: 0.371850
# Train Epoch:  10 [ 10240/ 99878 (10%)]	Loss: 0.439202
# Train Epoch:  10 [ 15360/ 99878 (15%)]	Loss: 0.434833
# Train Epoch:  10 [ 20480/ 99878 (20%)]	Loss: 0.462216
# Train Epoch:  10 [ 25600/ 99878 (26%)]	Loss: 0.449389
# Train Epoch:  10 [ 30720/ 99878 (31%)]	Loss: 0.444302
# Train Epoch:  10 [ 35840/ 99878 (36%)]	Loss: 0.453299
# Train Epoch:  10 [ 40960/ 99878 (41%)]	Loss: 0.465197
# Train Epoch:  10 [ 46080/ 99878 (46%)]	Loss: 0.445364
# Train Epoch:  10 [ 51200/ 99878 (51%)]	Loss: 0.413227
# Train Epoch:  10 [ 56320/ 99878 (56%)]	Loss: 0.470863
# Train Epoch:  10 [ 61440/ 99878 (61%)]	Loss: 0.459690
# Train Epoch:  10 [ 66560/ 99878 (66%)]	Loss: 0.439847
# Train Epoch:  10 [ 71680/ 99878 (71%)]	Loss: 0.450321
# Train Epoch:  10 [ 76800/ 99878 (77%)]	Loss: 0.469358
# Train Epoch:  10 [ 81920/ 99878 (82%)]	Loss: 0.437153
# Train Epoch:  10 [ 87040/ 99878 (87%)]	Loss: 0.438821
# Train Epoch:  10 [ 92160/ 99878 (92%)]	Loss: 0.459771
# Train Epoch:  10 [ 97280/ 99878 (97%)]	Loss: 0.490860
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 82877/99878 (82.98%)
#
#
# * * * Training * * *
# Train Epoch:  11 [     0/ 99878 (0%)]	Loss: 0.435342
# Train Epoch:  11 [  5120/ 99878 (5%)]	Loss: 0.429000
# Train Epoch:  11 [ 10240/ 99878 (10%)]	Loss: 0.442589
# Train Epoch:  11 [ 15360/ 99878 (15%)]	Loss: 0.441994
# Train Epoch:  11 [ 20480/ 99878 (20%)]	Loss: 0.433986
# Train Epoch:  11 [ 25600/ 99878 (26%)]	Loss: 0.411591
# Train Epoch:  11 [ 30720/ 99878 (31%)]	Loss: 0.406728
# Train Epoch:  11 [ 35840/ 99878 (36%)]	Loss: 0.447278
# Train Epoch:  11 [ 40960/ 99878 (41%)]	Loss: 0.425240
# Train Epoch:  11 [ 46080/ 99878 (46%)]	Loss: 0.415066
# Train Epoch:  11 [ 51200/ 99878 (51%)]	Loss: 0.432136
# Train Epoch:  11 [ 56320/ 99878 (56%)]	Loss: 0.434650
# Train Epoch:  11 [ 61440/ 99878 (61%)]	Loss: 0.456872
# Train Epoch:  11 [ 66560/ 99878 (66%)]	Loss: 0.478294
# Train Epoch:  11 [ 71680/ 99878 (71%)]	Loss: 0.443623
# Train Epoch:  11 [ 76800/ 99878 (77%)]	Loss: 0.449140
# Train Epoch:  11 [ 81920/ 99878 (82%)]	Loss: 0.431279
# Train Epoch:  11 [ 87040/ 99878 (87%)]	Loss: 0.411552
# Train Epoch:  11 [ 92160/ 99878 (92%)]	Loss: 0.428395
# Train Epoch:  11 [ 97280/ 99878 (97%)]	Loss: 0.398778
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 82961/99878 (83.06%)
#
#
# * * * Training * * *
# Train Epoch:  12 [     0/ 99878 (0%)]	Loss: 0.412990
# Train Epoch:  12 [  5120/ 99878 (5%)]	Loss: 0.414120
# Train Epoch:  12 [ 10240/ 99878 (10%)]	Loss: 0.431039
# Train Epoch:  12 [ 15360/ 99878 (15%)]	Loss: 0.409336
# Train Epoch:  12 [ 20480/ 99878 (20%)]	Loss: 0.483376
# Train Epoch:  12 [ 25600/ 99878 (26%)]	Loss: 0.433840
# Train Epoch:  12 [ 30720/ 99878 (31%)]	Loss: 0.425931
# Train Epoch:  12 [ 35840/ 99878 (36%)]	Loss: 0.409969
# Train Epoch:  12 [ 40960/ 99878 (41%)]	Loss: 0.404255
# Train Epoch:  12 [ 46080/ 99878 (46%)]	Loss: 0.398704
# Train Epoch:  12 [ 51200/ 99878 (51%)]	Loss: 0.425369
# Train Epoch:  12 [ 56320/ 99878 (56%)]	Loss: 0.437784
# Train Epoch:  12 [ 61440/ 99878 (61%)]	Loss: 0.435401
# Train Epoch:  12 [ 66560/ 99878 (66%)]	Loss: 0.423321
# Train Epoch:  12 [ 71680/ 99878 (71%)]	Loss: 0.440551
# Train Epoch:  12 [ 76800/ 99878 (77%)]	Loss: 0.427594
# Train Epoch:  12 [ 81920/ 99878 (82%)]	Loss: 0.443962
# Train Epoch:  12 [ 87040/ 99878 (87%)]	Loss: 0.452409
# Train Epoch:  12 [ 92160/ 99878 (92%)]	Loss: 0.407048
# Train Epoch:  12 [ 97280/ 99878 (97%)]	Loss: 0.405986
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83033/99878 (83.13%)
#
#
# * * * Training * * *
# Train Epoch:  13 [     0/ 99878 (0%)]	Loss: 0.434424
# Train Epoch:  13 [  5120/ 99878 (5%)]	Loss: 0.425838
# Train Epoch:  13 [ 10240/ 99878 (10%)]	Loss: 0.459885
# Train Epoch:  13 [ 15360/ 99878 (15%)]	Loss: 0.409751
# Train Epoch:  13 [ 20480/ 99878 (20%)]	Loss: 0.425385
# Train Epoch:  13 [ 25600/ 99878 (26%)]	Loss: 0.423106
# Train Epoch:  13 [ 30720/ 99878 (31%)]	Loss: 0.405903
# Train Epoch:  13 [ 35840/ 99878 (36%)]	Loss: 0.423777
# Train Epoch:  13 [ 40960/ 99878 (41%)]	Loss: 0.400474
# Train Epoch:  13 [ 46080/ 99878 (46%)]	Loss: 0.432081
# Train Epoch:  13 [ 51200/ 99878 (51%)]	Loss: 0.442408
# Train Epoch:  13 [ 56320/ 99878 (56%)]	Loss: 0.395872
# Train Epoch:  13 [ 61440/ 99878 (61%)]	Loss: 0.453825
# Train Epoch:  13 [ 66560/ 99878 (66%)]	Loss: 0.403063
# Train Epoch:  13 [ 71680/ 99878 (71%)]	Loss: 0.410881
# Train Epoch:  13 [ 76800/ 99878 (77%)]	Loss: 0.456992
# Train Epoch:  13 [ 81920/ 99878 (82%)]	Loss: 0.432371
# Train Epoch:  13 [ 87040/ 99878 (87%)]	Loss: 0.432995
# Train Epoch:  13 [ 92160/ 99878 (92%)]	Loss: 0.414163
# Train Epoch:  13 [ 97280/ 99878 (97%)]	Loss: 0.424572
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83078/99878 (83.18%)
#
#
# * * * Training * * *
# Train Epoch:  14 [     0/ 99878 (0%)]	Loss: 0.387258
# Train Epoch:  14 [  5120/ 99878 (5%)]	Loss: 0.428562
# Train Epoch:  14 [ 10240/ 99878 (10%)]	Loss: 0.434940
# Train Epoch:  14 [ 15360/ 99878 (15%)]	Loss: 0.422545
# Train Epoch:  14 [ 20480/ 99878 (20%)]	Loss: 0.405876
# Train Epoch:  14 [ 25600/ 99878 (26%)]	Loss: 0.448118
# Train Epoch:  14 [ 30720/ 99878 (31%)]	Loss: 0.421336
# Train Epoch:  14 [ 35840/ 99878 (36%)]	Loss: 0.451431
# Train Epoch:  14 [ 40960/ 99878 (41%)]	Loss: 0.411488
# Train Epoch:  14 [ 46080/ 99878 (46%)]	Loss: 0.452583
# Train Epoch:  14 [ 51200/ 99878 (51%)]	Loss: 0.435535
# Train Epoch:  14 [ 56320/ 99878 (56%)]	Loss: 0.452350
# Train Epoch:  14 [ 61440/ 99878 (61%)]	Loss: 0.404896
# Train Epoch:  14 [ 66560/ 99878 (66%)]	Loss: 0.454919
# Train Epoch:  14 [ 71680/ 99878 (71%)]	Loss: 0.443805
# Train Epoch:  14 [ 76800/ 99878 (77%)]	Loss: 0.387141
# Train Epoch:  14 [ 81920/ 99878 (82%)]	Loss: 0.460964
# Train Epoch:  14 [ 87040/ 99878 (87%)]	Loss: 0.403189
# Train Epoch:  14 [ 92160/ 99878 (92%)]	Loss: 0.437410
# Train Epoch:  14 [ 97280/ 99878 (97%)]	Loss: 0.435375
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83143/99878 (83.24%)
#
#
# * * * Training * * *
# Train Epoch:  15 [     0/ 99878 (0%)]	Loss: 0.429910
# Train Epoch:  15 [  5120/ 99878 (5%)]	Loss: 0.404457
# Train Epoch:  15 [ 10240/ 99878 (10%)]	Loss: 0.401176
# Train Epoch:  15 [ 15360/ 99878 (15%)]	Loss: 0.399058
# Train Epoch:  15 [ 20480/ 99878 (20%)]	Loss: 0.406186
# Train Epoch:  15 [ 25600/ 99878 (26%)]	Loss: 0.426744
# Train Epoch:  15 [ 30720/ 99878 (31%)]	Loss: 0.412006
# Train Epoch:  15 [ 35840/ 99878 (36%)]	Loss: 0.413713
# Train Epoch:  15 [ 40960/ 99878 (41%)]	Loss: 0.405775
# Train Epoch:  15 [ 46080/ 99878 (46%)]	Loss: 0.427976
# Train Epoch:  15 [ 51200/ 99878 (51%)]	Loss: 0.418925
# Train Epoch:  15 [ 56320/ 99878 (56%)]	Loss: 0.439450
# Train Epoch:  15 [ 61440/ 99878 (61%)]	Loss: 0.435318
# Train Epoch:  15 [ 66560/ 99878 (66%)]	Loss: 0.399391
# Train Epoch:  15 [ 71680/ 99878 (71%)]	Loss: 0.424171
# Train Epoch:  15 [ 76800/ 99878 (77%)]	Loss: 0.435021
# Train Epoch:  15 [ 81920/ 99878 (82%)]	Loss: 0.448181
# Train Epoch:  15 [ 87040/ 99878 (87%)]	Loss: 0.440645
# Train Epoch:  15 [ 92160/ 99878 (92%)]	Loss: 0.466353
# Train Epoch:  15 [ 97280/ 99878 (97%)]	Loss: 0.425021
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83156/99878 (83.26%)
#
#
# * * * Training * * *
# Train Epoch:  16 [     0/ 99878 (0%)]	Loss: 0.423754
# Train Epoch:  16 [  5120/ 99878 (5%)]	Loss: 0.390011
# Train Epoch:  16 [ 10240/ 99878 (10%)]	Loss: 0.457096
# Train Epoch:  16 [ 15360/ 99878 (15%)]	Loss: 0.475833
# Train Epoch:  16 [ 20480/ 99878 (20%)]	Loss: 0.443189
# Train Epoch:  16 [ 25600/ 99878 (26%)]	Loss: 0.447491
# Train Epoch:  16 [ 30720/ 99878 (31%)]	Loss: 0.441085
# Train Epoch:  16 [ 35840/ 99878 (36%)]	Loss: 0.407751
# Train Epoch:  16 [ 40960/ 99878 (41%)]	Loss: 0.446724
# Train Epoch:  16 [ 46080/ 99878 (46%)]	Loss: 0.418234
# Train Epoch:  16 [ 51200/ 99878 (51%)]	Loss: 0.440022
# Train Epoch:  16 [ 56320/ 99878 (56%)]	Loss: 0.401776
# Train Epoch:  16 [ 61440/ 99878 (61%)]	Loss: 0.413406
# Train Epoch:  16 [ 66560/ 99878 (66%)]	Loss: 0.380859
# Train Epoch:  16 [ 71680/ 99878 (71%)]	Loss: 0.428196
# Train Epoch:  16 [ 76800/ 99878 (77%)]	Loss: 0.410441
# Train Epoch:  16 [ 81920/ 99878 (82%)]	Loss: 0.434856
# Train Epoch:  16 [ 87040/ 99878 (87%)]	Loss: 0.412388
# Train Epoch:  16 [ 92160/ 99878 (92%)]	Loss: 0.407830
# Train Epoch:  16 [ 97280/ 99878 (97%)]	Loss: 0.415816
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83165/99878 (83.27%)
#
#
# * * * Training * * *
# Train Epoch:  17 [     0/ 99878 (0%)]	Loss: 0.427265
# Train Epoch:  17 [  5120/ 99878 (5%)]	Loss: 0.419255
# Train Epoch:  17 [ 10240/ 99878 (10%)]	Loss: 0.442348
# Train Epoch:  17 [ 15360/ 99878 (15%)]	Loss: 0.407500
# Train Epoch:  17 [ 20480/ 99878 (20%)]	Loss: 0.467079
# Train Epoch:  17 [ 25600/ 99878 (26%)]	Loss: 0.427222
# Train Epoch:  17 [ 30720/ 99878 (31%)]	Loss: 0.419571
# Train Epoch:  17 [ 35840/ 99878 (36%)]	Loss: 0.409375
# Train Epoch:  17 [ 40960/ 99878 (41%)]	Loss: 0.426055
# Train Epoch:  17 [ 46080/ 99878 (46%)]	Loss: 0.438132
# Train Epoch:  17 [ 51200/ 99878 (51%)]	Loss: 0.427868
# Train Epoch:  17 [ 56320/ 99878 (56%)]	Loss: 0.432773
# Train Epoch:  17 [ 61440/ 99878 (61%)]	Loss: 0.414507
# Train Epoch:  17 [ 66560/ 99878 (66%)]	Loss: 0.428177
# Train Epoch:  17 [ 71680/ 99878 (71%)]	Loss: 0.433728
# Train Epoch:  17 [ 76800/ 99878 (77%)]	Loss: 0.453834
# Train Epoch:  17 [ 81920/ 99878 (82%)]	Loss: 0.395542
# Train Epoch:  17 [ 87040/ 99878 (87%)]	Loss: 0.438972
# Train Epoch:  17 [ 92160/ 99878 (92%)]	Loss: 0.426249
# Train Epoch:  17 [ 97280/ 99878 (97%)]	Loss: 0.446044
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83177/99878 (83.28%)
#
#
# * * * Training * * *
# Train Epoch:  18 [     0/ 99878 (0%)]	Loss: 0.447686
# Train Epoch:  18 [  5120/ 99878 (5%)]	Loss: 0.427362
# Train Epoch:  18 [ 10240/ 99878 (10%)]	Loss: 0.434163
# Train Epoch:  18 [ 15360/ 99878 (15%)]	Loss: 0.413454
# Train Epoch:  18 [ 20480/ 99878 (20%)]	Loss: 0.472968
# Train Epoch:  18 [ 25600/ 99878 (26%)]	Loss: 0.424342
# Train Epoch:  18 [ 30720/ 99878 (31%)]	Loss: 0.417046
# Train Epoch:  18 [ 35840/ 99878 (36%)]	Loss: 0.391276
# Train Epoch:  18 [ 40960/ 99878 (41%)]	Loss: 0.456022
# Train Epoch:  18 [ 46080/ 99878 (46%)]	Loss: 0.406789
# Train Epoch:  18 [ 51200/ 99878 (51%)]	Loss: 0.430599
# Train Epoch:  18 [ 56320/ 99878 (56%)]	Loss: 0.420768
# Train Epoch:  18 [ 61440/ 99878 (61%)]	Loss: 0.413191
# Train Epoch:  18 [ 66560/ 99878 (66%)]	Loss: 0.401827
# Train Epoch:  18 [ 71680/ 99878 (71%)]	Loss: 0.438159
# Train Epoch:  18 [ 76800/ 99878 (77%)]	Loss: 0.423867
# Train Epoch:  18 [ 81920/ 99878 (82%)]	Loss: 0.401417
# Train Epoch:  18 [ 87040/ 99878 (87%)]	Loss: 0.418390
# Train Epoch:  18 [ 92160/ 99878 (92%)]	Loss: 0.411130
# Train Epoch:  18 [ 97280/ 99878 (97%)]	Loss: 0.446701
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83184/99878 (83.29%)
#
#
# * * * Training * * *
# Train Epoch:  19 [     0/ 99878 (0%)]	Loss: 0.425992
# Train Epoch:  19 [  5120/ 99878 (5%)]	Loss: 0.426326
# Train Epoch:  19 [ 10240/ 99878 (10%)]	Loss: 0.457935
# Train Epoch:  19 [ 15360/ 99878 (15%)]	Loss: 0.411393
# Train Epoch:  19 [ 20480/ 99878 (20%)]	Loss: 0.409424
# Train Epoch:  19 [ 25600/ 99878 (26%)]	Loss: 0.403508
# Train Epoch:  19 [ 30720/ 99878 (31%)]	Loss: 0.370912
# Train Epoch:  19 [ 35840/ 99878 (36%)]	Loss: 0.443443
# Train Epoch:  19 [ 40960/ 99878 (41%)]	Loss: 0.453319
# Train Epoch:  19 [ 46080/ 99878 (46%)]	Loss: 0.433307
# Train Epoch:  19 [ 51200/ 99878 (51%)]	Loss: 0.420907
# Train Epoch:  19 [ 56320/ 99878 (56%)]	Loss: 0.371966
# Train Epoch:  19 [ 61440/ 99878 (61%)]	Loss: 0.393224
# Train Epoch:  19 [ 66560/ 99878 (66%)]	Loss: 0.428397
# Train Epoch:  19 [ 71680/ 99878 (71%)]	Loss: 0.438072
# Train Epoch:  19 [ 76800/ 99878 (77%)]	Loss: 0.424820
# Train Epoch:  19 [ 81920/ 99878 (82%)]	Loss: 0.409859
# Train Epoch:  19 [ 87040/ 99878 (87%)]	Loss: 0.421372
# Train Epoch:  19 [ 92160/ 99878 (92%)]	Loss: 0.403305
# Train Epoch:  19 [ 97280/ 99878 (97%)]	Loss: 0.462482
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83181/99878 (83.28%)
#
#
# * * * Training * * *
# Train Epoch:  20 [     0/ 99878 (0%)]	Loss: 0.404083
# Train Epoch:  20 [  5120/ 99878 (5%)]	Loss: 0.428581
# Train Epoch:  20 [ 10240/ 99878 (10%)]	Loss: 0.363865
# Train Epoch:  20 [ 15360/ 99878 (15%)]	Loss: 0.434254
# Train Epoch:  20 [ 20480/ 99878 (20%)]	Loss: 0.433877
# Train Epoch:  20 [ 25600/ 99878 (26%)]	Loss: 0.393553
# Train Epoch:  20 [ 30720/ 99878 (31%)]	Loss: 0.435316
# Train Epoch:  20 [ 35840/ 99878 (36%)]	Loss: 0.420969
# Train Epoch:  20 [ 40960/ 99878 (41%)]	Loss: 0.448209
# Train Epoch:  20 [ 46080/ 99878 (46%)]	Loss: 0.378977
# Train Epoch:  20 [ 51200/ 99878 (51%)]	Loss: 0.439254
# Train Epoch:  20 [ 56320/ 99878 (56%)]	Loss: 0.406003
# Train Epoch:  20 [ 61440/ 99878 (61%)]	Loss: 0.442087
# Train Epoch:  20 [ 66560/ 99878 (66%)]	Loss: 0.469499
# Train Epoch:  20 [ 71680/ 99878 (71%)]	Loss: 0.437159
# Train Epoch:  20 [ 76800/ 99878 (77%)]	Loss: 0.377298
# Train Epoch:  20 [ 81920/ 99878 (82%)]	Loss: 0.427537
# Train Epoch:  20 [ 87040/ 99878 (87%)]	Loss: 0.442396
# Train Epoch:  20 [ 92160/ 99878 (92%)]	Loss: 0.436912
# Train Epoch:  20 [ 97280/ 99878 (97%)]	Loss: 0.406790
#
# * * * Evaluating * * *
# Test set: Average loss: 0.0004, Accuracy: 83195/99878 (83.30%)

# %%
print('Max val acc: {:.2f}%'.format(max(history['val_acc'])))
# Out:
# Max val acc: 83.30%

# %%
plt.plot(history['train_loss'])
plt.show()

# %%
plt.plot(history['val_acc'])
plt.show()
